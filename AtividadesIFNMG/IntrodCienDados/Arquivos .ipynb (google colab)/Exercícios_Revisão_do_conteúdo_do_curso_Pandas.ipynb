# %% [markdown]
# Lista de Exercícios - Revisão do conteúdo do curso Pandas do Kaggle 02.

# %% [markdown]
# 01) Carregue o arquivo GSAF5.xls.csv em uma variável denominada df definindo a primeira coluna do arquivo como o índice das linhas.
#
# Obs: O arquivo "GSAF5.xls.csv" pode ser encontrado em [Shark Attacks](https://www.kaggle.com/datasets/thedevastator/shark-attacks-the-risks-of-coastal-water-activit)

# %%
pip install googletrans==3.1.0a0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.7/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2022.9.24)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2022.11.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16370 sha256=ddfe84ad2a73103c910669c9b0ec36d9d9a82371d420701837ae0c80486b2c5e
#   Stored in directory: /root/.cache/pip/wheels/0c/be/fe/93a6a40ffe386e16089e44dad9018ebab9dc4cb9eb7eab65ae
# Successfully built googletrans
# Installing collected packages: googletrans
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 3.0.0
#     Uninstalling googletrans-3.0.0:
#       Successfully uninstalled googletrans-3.0.0
# Successfully installed googletrans-3.1.0a0

# %%
import pandas as pd
from googletrans import Translator

df = pd.read_csv('/content/GSAF5.xls - GSAF5.xls (1).csv', index_col = 0)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (10,17,18,19,20,21,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Case Number                  Date    Year        Type  \
# index
# 0        2020.02.05           05-Feb-2020  2020.0  Unprovoked
# 1      2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked
# 2        2020.01.17          17-jan.-2020  2020.0  Unprovoked
# 3        2020.01.16          16-jan.-2020  2020.0  Unprovoked
# 4        2020.01.13          13-jan.-2020  2020.0  Unprovoked
# ...             ...                   ...     ...         ...
# 6457        ND.0005           Before 1903     0.0  Unprovoked
# 6458        ND.0004           Before 1903     0.0  Unprovoked
# 6459        ND.0003             1900-1905     0.0  Unprovoked
# 6460        ND.0002             1883-1889     0.0  Unprovoked
# 6461        ND.0001             1845-1853     0.0  Unprovoked
#
#                   Country               Area  \
# index
# 0                     USA               Maui
# 1                 BAHAMAS             Exumas
# 2               AUSTRALIA    New South Wales
# 3             NEW ZEALAND          Southland
# 4                     USA     North Carolina
# ...                   ...                ...
# 6457            AUSTRALIA  Western Australia
# 6458            AUSTRALIA  Western Australia
# 6459                  USA     North Carolina
# 6460               PANAMA                NaN
# 6461   CEYLON (SRI LANKA)   Eastern Province
#
#                                   Location                  Activity  \
# index
# 0                                      NaN  Stand-Up Paddle boarding
# 1                                      NaN                  Floating
# 2                            Windang Beach                   Surfing
# 3                              Oreti Beach                   Surfing
# 4                    Rodanthe, Dare County                   Surfing
# ...                                    ...                       ...
# 6457                           Roebuck Bay                    Diving
# 6458                                   NaN              Pearl diving
# 6459                        Ocracoke Inlet                  Swimming
# 6460                  Panama Bay 8ºN, 79ºW                       NaN
# 6461   Below the English fort, Trincomalee                  Swimming
#
#                         Name Unnamed: 9  ... Unnamed: 246 Unnamed: 247  \
# index                                    ...
# 0                        NaN        NaN  ...          NaN          NaN
# 1            Ana Bruna Avila          F  ...          NaN          NaN
# 2             Will Schroeter          M  ...          NaN          NaN
# 3                Jordan King          F  ...          NaN          NaN
# 4               Samuel Horne          M  ...          NaN          NaN
# ...                      ...        ...  ...          ...          ...
# 6457                    male        NaN  ...          NaN          NaN
# 6458                   Ahmun        NaN  ...          NaN          NaN
# 6459   Coast Guard personnel        NaN  ...          NaN          NaN
# 6460         Jules Patterson        NaN  ...          NaN          NaN
# 6461                    male        NaN  ...          NaN          NaN
#
#       Unnamed: 248 Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252  \
# index
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 6457           NaN          NaN          NaN          NaN          NaN
# 6458           NaN          NaN          NaN          NaN          NaN
# 6459           NaN          NaN          NaN          NaN          NaN
# 6460           NaN          NaN          NaN          NaN          NaN
# 6461           NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 253 Unnamed: 254 Unnamed: 255
# index
# 0              NaN          NaN          NaN
# 1              NaN          NaN          NaN
# 2              NaN          NaN          NaN
# 3              NaN          NaN          NaN
# 4              NaN          NaN          NaN
# ...            ...          ...          ...
# 6457           NaN          NaN          NaN
# 6458           NaN          NaN          NaN
# 6459           NaN          NaN          NaN
# 6460           NaN          NaN          NaN
# 6461           NaN          NaN          NaN
#
# [6462 rows x 256 columns]

# %% [markdown]
# 02) Imprima as 8 primeiras linhas do DataFrame df.

# %%
df.head(8)
# Out:
#         Case Number                  Date    Year        Type      Country  \
# index
# 0        2020.02.05           05-Feb-2020  2020.0  Unprovoked          USA
# 1      2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2        2020.01.17          17-jan.-2020  2020.0  Unprovoked    AUSTRALIA
# 3        2020.01.16          16-jan.-2020  2020.0  Unprovoked  NEW ZEALAND
# 4        2020.01.13          13-jan.-2020  2020.0  Unprovoked          USA
# 5        2020.01.12          12-jan.-2020  2020.0  Unprovoked     THAILAND
# 6        2020.01.07          07-jan.-2020  2020.0  Unprovoked    AUSTRALIA
# 7        2020.01.05          05-jan.-2020  2020.0  Unprovoked    AUSTRALIA
#
#                      Area                 Location                  Activity  \
# index
# 0                    Maui                      NaN  Stand-Up Paddle boarding
# 1                  Exumas                      NaN                  Floating
# 2         New South Wales            Windang Beach                   Surfing
# 3               Southland              Oreti Beach                   Surfing
# 4          North Carolina    Rodanthe, Dare County                   Surfing
# 5      Phang Nga Province         Nang Thong Beach                  Swimming
# 6              Queensland        North West Island                  Swimming
# 7       Western Australia  Cull Island / Esperance              Scuba diving
#
#                     Name Unnamed: 9  ... Unnamed: 246 Unnamed: 247  \
# index                                ...
# 0                    NaN        NaN  ...          NaN          NaN
# 1        Ana Bruna Avila          F  ...          NaN          NaN
# 2         Will Schroeter          M  ...          NaN          NaN
# 3            Jordan King          F  ...          NaN          NaN
# 4           Samuel Horne          M  ...          NaN          NaN
# 5      Hans-Peter Malten          M  ...          NaN          NaN
# 6            Miah Holmes          F  ...          NaN          NaN
# 7           Gary Johnson          M  ...          NaN          NaN
#
#       Unnamed: 248 Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252  \
# index
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# 5              NaN          NaN          NaN          NaN          NaN
# 6              NaN          NaN          NaN          NaN          NaN
# 7              NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 253 Unnamed: 254 Unnamed: 255
# index
# 0              NaN          NaN          NaN
# 1              NaN          NaN          NaN
# 2              NaN          NaN          NaN
# 3              NaN          NaN          NaN
# 4              NaN          NaN          NaN
# 5              NaN          NaN          NaN
# 6              NaN          NaN          NaN
# 7              NaN          NaN          NaN
#
# [8 rows x 256 columns]

# %% [markdown]
# 03) Apresente a contagem de acidentes que acontenceram em cada pais. Ordene o resultado pela coluna pais de forma descendente.

# %%
df.groupby('Country')['Case Number'].count().sort_values(ascending = False)
# Out:
# Country
# USA                         2309
# AUSTRALIA                   1374
# SOUTH AFRICA                 585
# PAPUA NEW GUINEA             135
# NEW ZEALAND                  135
#                             ...
# OCEAN                          1
# NORTHERN MARIANA ISLANDS       1
# NORTHERN ARABIAN SEA           1
# NORTH SEA                      1
# ADMIRALTY ISLANDS              1
# Name: Case Number, Length: 205, dtype: int64

# %% [markdown]
# 04) Qual a atividade que mais gera acidentes com tubarões?

# %%
df.groupby("Activity")['Activity'].count().sort_values(ascending = False)
# Out:
# Activity
# Surfing                                         1025
# Swimming                                         932
# Fishing                                          459
# Spearfishing                                     350
# Bathing                                          166
#                                                 ...
# Fishing, standing in water washing fish            1
# Fishing, standing in water next to purse net       1
# Fishing, standing in waist-deep water              1
# Fishing, standing in 2' of water                   1
# yachtsman in a zodiac                              1
# Name: Activity, Length: 1516, dtype: int64

# %% [markdown]
# 05) É possível descobrir se existe alguma pessoa nesta base de dados que já tenha sofrido mais de um acidente com tubarões?

# %%
df['Name'].value_counts()
# Out:
# male                     579
# female                   106
# boy                       23
# 2 males                   19
# boat                      14
#                         ...
# Matt Kraskiewicz           1
# Norman Payne               1
# Henrietta Musselwhite      1
# Jason Licamele             1
# Jules Patterson            1
# Name: Name, Length: 5339, dtype: int64

# %% [markdown]
# 06) Quantos casos de Data Frame não possuem cadastro para a coluna 'Location'?

# %%
df.loc[df['Location'].isnull()]
# Out:
#         Case Number                  Date    Year          Type  \
# index
# 0        2020.02.05           05-Feb-2020  2020.0    Unprovoked
# 1      2020.01.30.R  Reported 30-Jan-2020  2020.0      Provoked
# 17       2019.12.12           12-Dec-2019  2019.0  Questionable
# 113    2018.12.15.b           15-Dec-2018  2018.0      Provoked
# 208      2017.12.09           09-Dec-2017  2017.0    Unprovoked
# ...             ...                   ...     ...           ...
# 6453        ND.0009           Before 1906     0.0    Unprovoked
# 6454        ND.0008           Before 1906     0.0    Unprovoked
# 6455        ND.0007           Before 1906     0.0    Unprovoked
# 6456        ND.0006           Before 1906     0.0    Unprovoked
# 6458        ND.0004           Before 1903     0.0    Unprovoked
#
#               Country               Area Location                  Activity  \
# index
# 0                 USA               Maui      NaN  Stand-Up Paddle boarding
# 1             BAHAMAS             Exumas      NaN                  Floating
# 17     REUNION ISLAND                NaN      NaN                  Kayaking
# 113         AUSTRALIA    New South Wales      NaN                       NaN
# 208           BAHAMAS                NaN      NaN                Snorkeling
# ...               ...                ...      ...                       ...
# 6453        AUSTRALIA                NaN      NaN                   Fishing
# 6454        AUSTRALIA                NaN      NaN                   Fishing
# 6455        AUSTRALIA                NaN      NaN                   Fishing
# 6456        AUSTRALIA    New South Wales      NaN                  Swimming
# 6458        AUSTRALIA  Western Australia      NaN              Pearl diving
#
#                       Name Unnamed: 9  ... Unnamed: 246 Unnamed: 247  \
# index                                  ...
# 0                      NaN        NaN  ...          NaN          NaN
# 1          Ana Bruna Avila          F  ...          NaN          NaN
# 17                     NaN          M  ...          NaN          NaN
# 113                   male        NaN  ...          NaN          NaN
# 208    Sarah Illig-Carroll        NaN  ...          NaN          NaN
# ...                    ...        ...  ...          ...          ...
# 6453                   boy        NaN  ...          NaN          NaN
# 6454             fisherman        NaN  ...          NaN          NaN
# 6455             fisherman        NaN  ...          NaN          NaN
# 6456              Arab boy        NaN  ...          NaN          NaN
# 6458                 Ahmun        NaN  ...          NaN          NaN
#
#       Unnamed: 248 Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252  \
# index
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 17             NaN          NaN          NaN          NaN          NaN
# 113            NaN          NaN          NaN          NaN          NaN
# 208            NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 6453           NaN          NaN          NaN          NaN          NaN
# 6454           NaN          NaN          NaN          NaN          NaN
# 6455           NaN          NaN          NaN          NaN          NaN
# 6456           NaN          NaN          NaN          NaN          NaN
# 6458           NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 253 Unnamed: 254 Unnamed: 255
# index
# 0              NaN          NaN          NaN
# 1              NaN          NaN          NaN
# 17             NaN          NaN          NaN
# 113            NaN          NaN          NaN
# 208            NaN          NaN          NaN
# ...            ...          ...          ...
# 6453           NaN          NaN          NaN
# 6454           NaN          NaN          NaN
# 6455           NaN          NaN          NaN
# 6456           NaN          NaN          NaN
# 6458           NaN          NaN          NaN
#
# [545 rows x 256 columns]

# %% [markdown]
# 07) Qual o tipo de dados da coluna Year?

# %%
df['Year'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# 08) Converta a coluna Year para int64. Sugestão: O parâmetro inplace pode ser utilizado para que a conversão seja gravada no Data Frame.

# %%
df['Year'].fillna(0)
df['Year'] = pd.to_numeric(df['Year'] , errors='coerce')

# %% [markdown]
# 09) Preencha todas as células vazias (NaN) da coluna Location com o termo 'Desconhecido'.

# %%
df['Location'].fillna('Desconhecido', inplace = True)
df
# Out:
#         Case Number                  Date    Year        Type  \
# index
# 0        2020.02.05           05-Feb-2020  2020.0  Unprovoked
# 1      2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked
# 2        2020.01.17          17-jan.-2020  2020.0  Unprovoked
# 3        2020.01.16          16-jan.-2020  2020.0  Unprovoked
# 4        2020.01.13          13-jan.-2020  2020.0  Unprovoked
# ...             ...                   ...     ...         ...
# 6457        ND.0005           Before 1903     0.0  Unprovoked
# 6458        ND.0004           Before 1903     0.0  Unprovoked
# 6459        ND.0003             1900-1905     0.0  Unprovoked
# 6460        ND.0002             1883-1889     0.0  Unprovoked
# 6461        ND.0001             1845-1853     0.0  Unprovoked
#
#                   Country               Area  \
# index
# 0                     USA               Maui
# 1                 BAHAMAS             Exumas
# 2               AUSTRALIA    New South Wales
# 3             NEW ZEALAND          Southland
# 4                     USA     North Carolina
# ...                   ...                ...
# 6457            AUSTRALIA  Western Australia
# 6458            AUSTRALIA  Western Australia
# 6459                  USA     North Carolina
# 6460               PANAMA                NaN
# 6461   CEYLON (SRI LANKA)   Eastern Province
#
#                                   Location                  Activity  \
# index
# 0                             Desconhecido  Stand-Up Paddle boarding
# 1                             Desconhecido                  Floating
# 2                            Windang Beach                   Surfing
# 3                              Oreti Beach                   Surfing
# 4                    Rodanthe, Dare County                   Surfing
# ...                                    ...                       ...
# 6457                           Roebuck Bay                    Diving
# 6458                          Desconhecido              Pearl diving
# 6459                        Ocracoke Inlet                  Swimming
# 6460                  Panama Bay 8ºN, 79ºW                       NaN
# 6461   Below the English fort, Trincomalee                  Swimming
#
#                         Name Unnamed: 9  ... Unnamed: 246 Unnamed: 247  \
# index                                    ...
# 0                        NaN        NaN  ...          NaN          NaN
# 1            Ana Bruna Avila          F  ...          NaN          NaN
# 2             Will Schroeter          M  ...          NaN          NaN
# 3                Jordan King          F  ...          NaN          NaN
# 4               Samuel Horne          M  ...          NaN          NaN
# ...                      ...        ...  ...          ...          ...
# 6457                    male        NaN  ...          NaN          NaN
# 6458                   Ahmun        NaN  ...          NaN          NaN
# 6459   Coast Guard personnel        NaN  ...          NaN          NaN
# 6460         Jules Patterson        NaN  ...          NaN          NaN
# 6461                    male        NaN  ...          NaN          NaN
#
#       Unnamed: 248 Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252  \
# index
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 6457           NaN          NaN          NaN          NaN          NaN
# 6458           NaN          NaN          NaN          NaN          NaN
# 6459           NaN          NaN          NaN          NaN          NaN
# 6460           NaN          NaN          NaN          NaN          NaN
# 6461           NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 253 Unnamed: 254 Unnamed: 255
# index
# 0              NaN          NaN          NaN
# 1              NaN          NaN          NaN
# 2              NaN          NaN          NaN
# 3              NaN          NaN          NaN
# 4              NaN          NaN          NaN
# ...            ...          ...          ...
# 6457           NaN          NaN          NaN
# 6458           NaN          NaN          NaN
# 6459           NaN          NaN          NaN
# 6460           NaN          NaN          NaN
# 6461           NaN          NaN          NaN
#
# [6462 rows x 256 columns]

# %% [markdown]
# 10) Faça a tradução da coluna Type substituindo os termos em inflês por seus respectivos termos em português.

# %%
tradutor = Translator()
lista = ['Unprovoked', 'Provoked', 'Invalid','Sea Disaster', 'Watercraft', 'Boat', 'Boating', 'Questionable', 'Unconfirmed', 'Unverified', 'Under investigation', 'Boatomg']
traducoes = tradutor.translate(lista, src='en', dest='pt')
a = 0
for traducao in traducoes[0:12]:
  print(traducoes[a].origin, '-->', traducoes[a].text)
  a += 1
# Out:
# Unprovoked --> Não provocado
# Provoked --> Provocado
# Invalid --> Inválido
# Sea Disaster --> Desastre Marítimo
# Watercraft --> Embarcação
# Boat --> Barco
# Boating --> Passeios de barco
# Questionable --> Questionável
# Unconfirmed --> Não confirmado
# Unverified --> Não verificado
# Under investigation --> Sob investigação
# Boatomg --> Boatomg

# %%
df['Type'].replace({'Unprovoked': traducoes[0], 'Provoked' : traducoes[1], 'Invalid' : traducoes[2], 'Sea Disaster' : traducoes[3],
                    'Watercraft' : traducoes[4], 'Boat' : traducoes[5], 'Boating' : traducoes[6], 'Questionable' : traducoes[7],
                    'Unconfirmed' : traducoes[8], 'Unverified' : traducoes[9], 'Under investigation' : traducoes[10], 'Boatomg' : traducoes[11]}, inplace = True)
df
# Out:
#         Case Number                  Date    Year           Type  \
# index
# 0        2020.02.05           05-Feb-2020  2020.0  Não provocado
# 1      2020.01.30.R  Reported 30-Jan-2020  2020.0      Provocado
# 2        2020.01.17          17-jan.-2020  2020.0  Não provocado
# 3        2020.01.16          16-jan.-2020  2020.0  Não provocado
# 4        2020.01.13          13-jan.-2020  2020.0  Não provocado
# ...             ...                   ...     ...            ...
# 6457        ND.0005           Before 1903     0.0  Não provocado
# 6458        ND.0004           Before 1903     0.0  Não provocado
# 6459        ND.0003             1900-1905     0.0  Não provocado
# 6460        ND.0002             1883-1889     0.0  Não provocado
# 6461        ND.0001             1845-1853     0.0  Não provocado
#
#                   Country               Area  \
# index
# 0                     USA               Maui
# 1                 BAHAMAS             Exumas
# 2               AUSTRALIA    New South Wales
# 3             NEW ZEALAND          Southland
# 4                     USA     North Carolina
# ...                   ...                ...
# 6457            AUSTRALIA  Western Australia
# 6458            AUSTRALIA  Western Australia
# 6459                  USA     North Carolina
# 6460               PANAMA                NaN
# 6461   CEYLON (SRI LANKA)   Eastern Province
#
#                                   Location                  Activity  \
# index
# 0                                      NaN  Stand-Up Paddle boarding
# 1                                      NaN                  Floating
# 2                            Windang Beach                   Surfing
# 3                              Oreti Beach                   Surfing
# 4                    Rodanthe, Dare County                   Surfing
# ...                                    ...                       ...
# 6457                           Roebuck Bay                    Diving
# 6458                                   NaN              Pearl diving
# 6459                        Ocracoke Inlet                  Swimming
# 6460                  Panama Bay 8ºN, 79ºW                       NaN
# 6461   Below the English fort, Trincomalee                  Swimming
#
#                         Name Sexo  ... Unnamed: 246 Unnamed: 247 Unnamed: 248  \
# index                              ...
# 0                        NaN  NaN  ...          NaN          NaN          NaN
# 1            Ana Bruna Avila    F  ...          NaN          NaN          NaN
# 2             Will Schroeter    M  ...          NaN          NaN          NaN
# 3                Jordan King    F  ...          NaN          NaN          NaN
# 4               Samuel Horne    M  ...          NaN          NaN          NaN
# ...                      ...  ...  ...          ...          ...          ...
# 6457                    male  NaN  ...          NaN          NaN          NaN
# 6458                   Ahmun  NaN  ...          NaN          NaN          NaN
# 6459   Coast Guard personnel  NaN  ...          NaN          NaN          NaN
# 6460         Jules Patterson  NaN  ...          NaN          NaN          NaN
# 6461                    male  NaN  ...          NaN          NaN          NaN
#
#       Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252 Unnamed: 253  \
# index
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 6457           NaN          NaN          NaN          NaN          NaN
# 6458           NaN          NaN          NaN          NaN          NaN
# 6459           NaN          NaN          NaN          NaN          NaN
# 6460           NaN          NaN          NaN          NaN          NaN
# 6461           NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 254 Unnamed: 255
# index
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ...            ...          ...
# 6457           NaN          NaN
# 6458           NaN          NaN
# 6459           NaN          NaN
# 6460           NaN          NaN
# 6461           NaN          NaN
#
# [6462 rows x 256 columns]

# %% [markdown]
# 11) Renomeie a coluna 'Unnamed: 9' para 'Sexo'.

# %%
df = df.rename(columns={'Unnamed: 9' : 'Sexo'})
df
# Out:
#         Case Number                  Date    Year        Type  \
# index
# 0        2020.02.05           05-Feb-2020  2020.0  Unprovoked
# 1      2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked
# 2        2020.01.17          17-jan.-2020  2020.0  Unprovoked
# 3        2020.01.16          16-jan.-2020  2020.0  Unprovoked
# 4        2020.01.13          13-jan.-2020  2020.0  Unprovoked
# ...             ...                   ...     ...         ...
# 6457        ND.0005           Before 1903     0.0  Unprovoked
# 6458        ND.0004           Before 1903     0.0  Unprovoked
# 6459        ND.0003             1900-1905     0.0  Unprovoked
# 6460        ND.0002             1883-1889     0.0  Unprovoked
# 6461        ND.0001             1845-1853     0.0  Unprovoked
#
#                   Country               Area  \
# index
# 0                     USA               Maui
# 1                 BAHAMAS             Exumas
# 2               AUSTRALIA    New South Wales
# 3             NEW ZEALAND          Southland
# 4                     USA     North Carolina
# ...                   ...                ...
# 6457            AUSTRALIA  Western Australia
# 6458            AUSTRALIA  Western Australia
# 6459                  USA     North Carolina
# 6460               PANAMA                NaN
# 6461   CEYLON (SRI LANKA)   Eastern Province
#
#                                   Location                  Activity  \
# index
# 0                                      NaN  Stand-Up Paddle boarding
# 1                                      NaN                  Floating
# 2                            Windang Beach                   Surfing
# 3                              Oreti Beach                   Surfing
# 4                    Rodanthe, Dare County                   Surfing
# ...                                    ...                       ...
# 6457                           Roebuck Bay                    Diving
# 6458                                   NaN              Pearl diving
# 6459                        Ocracoke Inlet                  Swimming
# 6460                  Panama Bay 8ºN, 79ºW                       NaN
# 6461   Below the English fort, Trincomalee                  Swimming
#
#                         Name Sexo  ... Unnamed: 246 Unnamed: 247 Unnamed: 248  \
# index                              ...
# 0                        NaN  NaN  ...          NaN          NaN          NaN
# 1            Ana Bruna Avila    F  ...          NaN          NaN          NaN
# 2             Will Schroeter    M  ...          NaN          NaN          NaN
# 3                Jordan King    F  ...          NaN          NaN          NaN
# 4               Samuel Horne    M  ...          NaN          NaN          NaN
# ...                      ...  ...  ...          ...          ...          ...
# 6457                    male  NaN  ...          NaN          NaN          NaN
# 6458                   Ahmun  NaN  ...          NaN          NaN          NaN
# 6459   Coast Guard personnel  NaN  ...          NaN          NaN          NaN
# 6460         Jules Patterson  NaN  ...          NaN          NaN          NaN
# 6461                    male  NaN  ...          NaN          NaN          NaN
#
#       Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252 Unnamed: 253  \
# index
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 6457           NaN          NaN          NaN          NaN          NaN
# 6458           NaN          NaN          NaN          NaN          NaN
# 6459           NaN          NaN          NaN          NaN          NaN
# 6460           NaN          NaN          NaN          NaN          NaN
# 6461           NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 254 Unnamed: 255
# index
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ...            ...          ...
# 6457           NaN          NaN
# 6458           NaN          NaN
# 6459           NaN          NaN
# 6460           NaN          NaN
# 6461           NaN          NaN
#
# [6462 rows x 256 columns]
